# %% [markdown]
# ### Install library Keras

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.3.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.17.3)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.8.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)

# %%
# !git clone https://github.com/keras-team/keras.git
# Out:
# Cloning into 'keras'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 32987 (delta 1), reused 3 (delta 0), pack-reused 32982
# Receiving objects: 100% (32987/32987), 13.02 MiB | 25.69 MiB/s, done.
# Resolving deltas: 100% (24113/24113), done.

# %% [markdown]
# ### Dataset FMNIST

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_lables) = fashion_mnist.load_data()

# %%
plt.figure()
plt.imshow(train_images[2])
plt.colorbar()
plt.grid(False)

# %%
class_names = ["Tshirt", "Celana Panjang", "Hoodie", "Kemeja", "Jaket", "Sandal", "Kaos", "Sneaker", "Tas", "Sepatu"]

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[train_labels[i]])

# %%
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128, activation=tf.nn.relu),
                          keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer=tf.train.AdamOptimizer(),
              loss = "sparse_categorical_crossentropy",
              metrics = ["accuracy"])
model.fit(train_images, train_labels, epochs=9)
# Out:
# Train on 60000 samples
# Epoch 1/9
# 60000/60000 [==============================] - 4s 67us/sample - loss: 3.2660 - acc: 0.6900
# Epoch 2/9
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.6954 - acc: 0.7327
# Epoch 3/9
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.6120 - acc: 0.7662
# Epoch 4/9
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.5715 - acc: 0.8004
# Epoch 5/9
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.5266 - acc: 0.8179
# Epoch 6/9
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.5055 - acc: 0.8253
# Epoch 7/9
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.4962 - acc: 0.8294
# Epoch 8/9
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.4937 - acc: 0.8305
# Epoch 9/9
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.4813 - acc: 0.8336

# %%
test_loss, test_acc = model.evaluate(test_images, test_lables)
print("Accuracy:", test_acc)
# Out:
# 10000/10000 [==============================] - 0s 30us/sample - loss: 0.6167 - acc: 0.7894
# Accuracy: 0.7894

# %%
i = 14
plt.figure(figsize=(4,4))
plt.subplot(2,2,2)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, prediction, test_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-d4eeeaa9ddb5> in <module>()
#       2 plt.figure(figsize=(4,4))
#       3 plt.subplot(2,2,2)
# ----> 4 plot_image(i, predictions, test_labels, test_images)
#       5 plt.subplot(1,2,2)
#       6 plot_value_array(i, prediction, test_labels)
#
# NameError: name 'plot_image' is not defined

# %%
i = 14
num_rows = 5
num_cols = 4
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
 plt.subplot(num_rows, 2*num_cols, 2*i+1)
 plot_image(i, predictions, test_lables, test_images)
 plt.subplot(num_rows, 2*num_cols, 2*i+2)
 plot_value_array(i, predictions, test_lables)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-3fdfc8bd8a87> in <module>()
#       6 for i in range(num_images):
#       7  plt.subplot(num_rows, 2*num_cols, 2*i+1)
# ----> 8  plot_image(i, predictions, test_lables, test_images)
#       9  plt.subplot(num_rows, 2*num_cols, 2*i+2)
#      10  plot_value_array(i, predictions, test_lables)
#
# NameError: name 'plot_image' is not defined
